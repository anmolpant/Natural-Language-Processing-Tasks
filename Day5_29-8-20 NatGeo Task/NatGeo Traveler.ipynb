# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
def extract_doc(doc):
    f = open(doc,"r", encoding='utf-8')
    data = f.read()
    word_tokens = word_tokenize(data)
    stop_words = list(set(stopwords.words('english')))
    filtered_sentence = []
    stopwords_list = []
    for w in word_tokens: 
        if w not in stop_words: 
            filtered_sentence.append(w)
        else:
            stopwords_list.append(w)
    
    return filtered_sentence

# %%
d1 = extract_doc(r"C:\Users\anmol\Downloads\natgeo1.txt")
d2 = extract_doc(r"C:\Users\anmol\Downloads\natgeo2.txt")
d3 = extract_doc(r"C:\Users\anmol\Downloads\natgeo3.txt")
d4 = extract_doc(r"C:\Users\anmol\Downloads\natgeo4.txt")
d5 = extract_doc(r"C:\Users\anmol\Downloads\sample.txt")

# %%
distinct_words = list(set(d1+d2+d3+d4+d5))

# %%
distinct_words
# Out:
# ['moment',
#  'genuinely',
#  'precisely',
#  'book',
#  'three',
#  'MotorcycleDiaries.',
#  'itinerary',
#  'manifold',
#  'dominated',
#  'exotification',
#  'befitting',
#  'storied',
#  'server—a',
#  'recalls',
#  'physical',
#  'paramours',
#  'purse-strings',
#  'infinitely',
#  'glances',
#  'Hampi',
#  'made-for-Instagram',
#  'Age-style',
#  'Tel',
#  'colourful',
#  ')',
#  'differed',
#  'backpacking',
#  'Besides',
#  'Kala',
#  'alleys',
#  'Local',
#  'thinking',
#  'hosting',
#  'Golightly',
#  'attempts',
#  'former',
#  'Where',
#  'madcap',
#  'filthy',
#  'holidays',
#  'blame',
#  'others',
#  'Le',
#  'dull',
#  'radioactive',
#  'Chinmai',
#  'day',
#  'By',
#  'followed',
#  'Olympics',
#  'writers',
#  'temperament',
#  'beeline',
#  'held',
#  'weekend',
#  'Bewildering',
#  'standing',
#  'special',
#  'De',
#  'hard-knock',
#  'food',
#  'pride',
#  'feeling',
#  'sidewalks',
#  'Luxury',
#  'Shillong',
#  'exclamations',
#  'smacked',
#  'nightclub',
#  'sentiments',
#  'Dixit',
#  'finest',
#  'Rome',
#  'York',
#  'About',
#  'confound',
#  'surprises',
#  'tried',
#  'unearthed',
#  'kind',
#  'chose',
#  'usually',
#  'travel',
#  'reminisces',
#  'Yorkers',
#  'privileges',
#  'perfect',
#  'VT',
#  'drinking',
#  'team',
#  'places',
#  'Mark',
#  'They',
#  'capital',
#  ',',
#  'dinner',
#  'functions',
#  'fork',
#  'on…',
#  'nightclubs',
#  'achievement',
#  'regret',
#  'immune',
#  'histories',
#  'China',
#  'notice',
#  'Taylor',
#  'attempting',
#  'Suspicions',
#  'Ardent',
#  'torment',
#  'Anthony',
#  'fall',
#  'Travel',
#  'champagne',
#  'gallivanting',
#  'besotted',
#  'It',
#  'got',
#  'admiration',
#  'reach',
#  'sample',
#  'turn',
#  'grasp',
#  'asked',
#  'people',
#  'regular',
#  'adventurous',
#  'hour',
#  'Banaras',
#  'restaurant',
#  'confirmed',
#  'Love',
#  'lucky',
#  'fortnight',
#  'eccentric',
#  'found',
#  'several',
#  'happy',
#  'greatest',
#  'matter',
#  'snobs',
#  'home',
#  'respond',
#  'wrote',
#  'stopped',
#  'even',
#  'contrast',
#  'Extravagance',
#  'passes',
#  'drives',
#  'highways',
#  'kick',
#  'revelries',
#  'sayings',
#  'stand',
#  'bunch',
#  'Chantilly',
#  'cocktail',
#  'moving',
#  'man',
#  'somewhere',
#  'south',
#  'maestros',
#  'proud',
#  'Abhishek',
#  'gates',
#  'it.',
#  'towards',
#  'feelings',
#  'fielding',
#  'centre',
#  'little',
#  'road',
#  'toasts',
#  'royalty',
#  'mayhem',
#  'changed',
#  'no-nonsense',
#  'institutions—a',
#  'showing',
#  'graduation',
#  'fun',
#  'Gupta',
#  'heiress',
#  'gnawing',
#  'caused',
#  'finish',
#  'veer',
#  'South',
#  'went',
#  'Bangladesh',
#  'present-day',
#  'wistful',
#  'gospel',
#  'Thomas',
#  'Wealth',
#  'indulge',
#  'Yes.',
#  'Delhi',
#  'someday',
#  'filling',
#  'Wresting',
#  'marvel',
#  'yet',
#  'inconvenienced',
#  'show',
#  'Turkey.',
#  'tourists',
#  '?',
#  'sensuality',
#  'every',
#  'inimitable',
#  'spurs',
#  'pesky',
#  'Maldives',
#  'predilections',
#  'relation',
#  'whether',
#  'cities',
#  'different',
#  '—the',
#  ':',
#  'Hacks',
#  'wish',
#  'answer',
#  'study',
#  '10-minute',
#  'preach',
#  'ground',
#  'fuss',
#  'never',
#  'independent',
#  'ruins',
#  'first',
#  'unsentimental',
#  'Anniversary',
#  'Who',
#  'devout',
#  'harp',
#  'glowing',
#  'overpriced',
#  'declared',
#  'rest',
#  'person',
#  'inner',
#  'Traveller',
#  'think',
#  'Islam',
#  'stumble',
#  'Days',
#  'crooked',
#  'relationship',
#  'sweaty',
#  'granted',
#  'Antoine',
#  'nooks',
#  'injury',
#  'David',
#  '0',
#  'land',
#  'end',
#  'esteem',
#  'fill',
#  'Dubai',
#  'mystical',
#  'relocating',
#  'culture',
#  'unwarranted',
#  'France',
#  'Go',
#  'wrong',
#  '’',
#  'parsed',
#  'claim',
#  'pow-wow',
#  'exploration',
#  'handful',
#  'riveted',
#  'dramatic',
#  'often',
#  'meal',
#  'We',
#  'replaying',
#  'part-endearing',
#  'hotel',
#  'Jazz',
#  'experienced',
#  'dances',
#  'practising',
#  'overrated',
#  'appetite',
#  'tiffs',
#  'feasts',
#  'journey',
#  'days',
#  'Let',
#  'nice',
#  'flirting',
#  '”',
#  'fine',
#  'stretch',
#  'things',
#  'habit',
#  'extolling',
#  'rise',
#  'decodes',
#  'ode',
#  'pleasures',
#  'For',
#  'Shangri-La',
#  'sea',
#  'told',
#  'month',
#  'flâneur',
#  'Some',
#  'favourite',
#  'baklava—a',
#  'local',
#  'history',
#  'pristine',
#  'city',
#  'pang',
#  'binge',
#  'surprising',
#  'Dubrovnik',
#  'coming',
#  'Like',
#  'Hyderabad',
#  'privy',
#  'urban',
#  'manors',
#  'right',
#  'Indian-American',
#  'Einstein',
#  'sometimes',
#  'guide',
#  'setting',
#  'destined',
#  'castles',
#  'reap',
#  'live',
#  'thank',
#  'emboldened',
#  'romance',
#  'Of',
#  'Arabian',
#  'profile',
#  'Lewis',
#  'metropolis',
#  'That',
#  'Hudson',
#  'messy',
#  'heritage',
#  'measure',
#  'better',
#  'Rajasthan',
#  'lowdown',
#  'pejorative',
#  'everyday',
#  'emerging',
#  'perusing',
#  'loafer',
#  'keep',
#  'reminder',
#  'reading',
#  'In',
#  'minimalists',
#  'stays',
#  'Bauhaus',
#  'He',
#  'could',
#  'readers',
#  'Now—As',
#  'substantial',
#  'comfortable',
#  'leave',
#  'Europe',
#  'journeys',
#  'gully',
#  'stay',
#  'Goa',
#  'year',
#  'minimum',
#  'Finland',
#  'grand',
#  'repulsed',
#  'schooling',
#  'forays',
#  'unknown',
#  'walks',
#  'game',
#  'options',
#  'Forget',
#  'Hajela',
#  'incoming',
#  'without',
#  'connections',
#  'baklava',
#  'dry',
#  'tutorial',
#  'backpack',
#  'pilgrimage',
#  'trudging',
#  'curries',
#  'Libya',
#  'circuitous',
#  'seems',
#  'acutely',
#  'seek',
#  'later',
#  'recreational',
#  'worst',
#  'Long',
#  'buy',
#  'across',
#  'Nobel',
#  'shade',
#  'truth',
#  'cuts',
#  '1990s',
#  'tourist',
#  'context',
#  'never-ending',
#  'solutions',
#  'English',
#  'Grecian',
#  'September',
#  'fairly',
#  ';',
#  'West',
#  'far',
#  'Train',
#  'conundrum',
#  'entitlement',
#  'permitted',
#  'also',
#  'featured',
#  'Usain',
#  'lay',
#  'What',
#  'spikier',
#  'unrequited',
#  'friend',
#  'faraway',
#  'settle',
#  'unlike',
#  'billionaire',
#  'decadence',
#  'ill-prepared',
#  'battles',
#  'unforgettable',
#  'madness',
#  'rephrase',
#  'One',
#  'spell',
#  'escape',
#  'slogging',
#  'trying',
#  'stories',
#  'As',
#  'To',
#  'Professional',
#  'Akhil',
#  'Mumbai',
#  'drummed',
#  'ocean',
#  'Janeiro',
#  'parts',
#  'glass',
#  'rebellion—oh',
#  'editions',
#  'Times',
#  'paeans',
#  'avowed',
#  'spectacle',
#  'Atala',
#  'Lumpur',
#  'writer',
#  'grace',
#  'Our',
#  'sweet',
#  'bond',
#  'Smart',
#  'undercurrents',
#  'hidden',
#  'gluttony',
#  'getting',
#  'sleep',
#  'Belfast',
#  'stance',
#  'Shashi',
#  'face',
#  'last',
#  'Sizing',
#  'This',
#  'Molotov',
#  'Twain',
#  'wanderlust.',
#  'locals',
#  'directed',
#  'assure',
#  'predictability',
#  'list',
#  'anniversary',
#  'navigate',
#  'access',
#  'gaudy',
#  'unchaperoned',
#  'haleem',
#  'descriptors',
#  'entries',
#  'Korea',
#  'Tiffany',
#  'shrines',
#  'Rorschach',
#  'pulse',
#  'modern',
#  'biases',
#  'seen',
#  'Live',
#  'His',
#  'past',
#  'chronicle',
#  'wallet',
#  'And',
#  'games',
#  'issue',
#  'steak',
#  'producing',
#  'tastes',
#  'memorable',
#  'Last',
#  'Then',
#  'test',
#  'monk',
#  'Thiruvananthapuram',
#  'dazed',
#  'section',
#  'gauche',
#  'eatery',
#  'kitchen',
#  'crudest',
#  'impression',
#  'owner',
#  'country',
#  'business',
#  'Flash',
#  'fruit-laden',
#  'knowing',
#  'domestic',
#  'travellers',
#  'over.',
#  'fully',
#  'bitter',
#  'elite',
#  'leaning',
#  'cafés',
#  'lived',
#  'stern',
#  'overflowing',
#  'haunts',
#  'passing',
#  'sigh',
#  'characters',
#  'ways',
#  'ever',
#  'roundup',
#  'Arre',
#  'financial',
#  'join',
#  'intertwined',
#  'bravado',
#  'dessert',
#  'stench',
#  'deserve',
#  'love',
#  '13',
#  'café',
#  'moniker',
#  'true',
#  'NGTI',
#  'four',
#  'almost',
#  'mainland',
#  'Craig',
#  'look',
#  'question',
#  'wink',
#  'India',
#  'picks',
#  'red',
#  'go',
#  'Iranian',
#  'Bolt',
#  'sixth',
#  'Indians',
#  'Read',
#  'travelling',
#  'enjoys',
#  'Nights',
#  'maybe',
#  'might',
#  'Canteen',
#  'sings',
#  'solo',
#  'unpack',
#  'beauty',
#  'desi',
#  'give',
#  'staple',
#  'How',
#  'head',
#  'destination',
#  'place',
#  'grappling',
#  'coverage',
#  'growing',
#  'fight',
#  'Rhythm',
#  'train',
#  'oldest',
#  'dreamers',
#  'gyrating',
#  'House',
#  'Japan',
#  'features',
#  'views',
#  'back',
#  'Ghoda',
#  'ephemeral',
#  'millions',
#  'credentials',
#  'number',
#  'complaints',
#  'side',
#  'slacking',
#  'abroad',
#  'aspire',
#  'nothing—floating',
#  'spent—or',
#  'Holly',
#  'penny',
#  'best',
#  'money',
#  'traditional',
#  'bite',
#  'rounded',
#  'way',
#  'December',
#  'smiles',
#  'If',
#  'worth',
#  'words',
#  'today',
#  'evokes',
#  '10',
#  'Bourdain',
#  'Milan',
#  'featuring',
#  'French',
#  'dives',
#  'get',
#  'observations',
#  'another',
#  'see',
#  'Ladakh',
#  'years',
#  'would',
#  'lies',
#  'Geographic',
#  'flagbearer',
#  'prompted',
#  'reclusive',
#  'centrepiece',
#  'guidebook-toting',
#  '!',
#  'heart',
#  'shopping',
#  'trails',
#  'particularly',
#  'gentleman',
#  'narratives',
#  'universal',
#  'offers',
#  'always',
#  'baba',
#  'cruise',
#  'Chef',
#  'There',
#  'atop',
#  'requested',
#  'authenticity',
#  'personal',
#  'wonderful',
#  'promise',
#  'skin',
#  'drool-worthy',
#  'take',
#  'two-way',
#  'New',
#  'allure',
#  'must-haves',
#  'celebrated',
#  'itineraries',
#  'Left',
#  'Sharma',
#  'dashed',
#  'jungle',
#  'companions',
#  'conservatively',
#  'confines',
#  'hardly',
#  'shop',
#  'downsizers',
#  'magazine',
#  'mouths',
#  'one…',
#  'astute',
#  'nostalgic',
#  'really',
#  'anywhere',
#  'Bengal',
#  'landscape',
#  'adopted',
#  'example',
#  'lasting',
#  'expert',
#  'call',
#  'Dyed-in-the-wool',
#  'tales',
#  'us',
#  'discovered',
#  'America',
#  'attitudes',
#  'Dinakaran',
#  'pride—we',
#  'Reema',
#  'window',
#  'turbulent',
#  'Unable',
#  'heartfelt',
#  'ultra-indulgence',
#  'became',
#  'pretend',
#  'uttering',
#  'Travellers',
#  'digs',
#  'vibrancy',
#  'incumbent',
#  'pure',
#  'spend',
#  'insights',
#  'gives',
#  'typical',
#  'simply',
#  'reveals',
#  'mind',
#  'insiders',
#  'five',
#  'pow-wow.',
#  'irresistible',
#  'trash',
#  'bus',
#  'eternally',
#  'Spotting',
#  'choose',
#  'Albert',
#  'barely',
#  'crowded',
#  'Hate',
#  'sunglasses',
#  'When',
#  'Those',
#  'wars',
#  'pair',
#  'brave',
#  'strong',
#  'someone',
#  'After',
#  'khau',
#  'eyebrow-cocked',
#  'National',
#  'well',
#  'misplaced',
#  'precarious',
#  'British',
#  'paradises',
#  'retreats',
#  'dishes',
#  'night',
#  'affection',
#  'taught',
#  'big',
#  'A',
#  'compatriot',
#  'amends',
#  'guided',
#  'hankering',
#  'cad',
#  'Kuala',
#  'swirling',
#  'come',
#  'flits',
#  'use',
#  'prepared',
#  'tell',
#  'bistro',
#  'term',
#  'examples',
#  'London',
#  'counter',
#  'Janice',
#  'venue',
#  'interesting',
#  'obtuse…',
#  'like',
#  'consider',
#  'either',
#  'flush',
#  'feel',
#  'meat',
#  'streets',
#  'subway',
#  'She',
#  'music',
#  'pugilistic',
#  'August',
#  'especially',
#  'Rio',
#  'All',
#  'year-end',
#  'media',
#  'elegant',
#  'global',
#  'aesthetes',
#  'Riviera',
#  'one',
#  'comes',
#  'brutal',
#  'divided',
#  'hurt',
#  'open-minded',
#  'bound',
#  'Vaishali',
#  'Mysore',
#  'Living',
#  'seemed',
#  'Bewitching',
#  'chalkboard',
#  'pens',
#  'casual',
#  'warmed',
#  'dispatches',
#  'luxury',
#  'hedonistic',
#  'maiden',
#  'Londoners',
#  'cosy',
#  'time',
#  'panders',
#  'countryside',
#  'air',
#  'ballroom',
#  'loses',
#  'Raghu',
#  'new',
#  'Bring',
#  'curdle',
#  'Tharoor',
#  'me.',
#  'Member',
#  'musician',
#  'making',
#  'philosophers',
#  'desperately-trying-to-be-hip',
#  'distillation',
#  'fertile',
#  'precise',
#  'Kolkata',
#  'unrepentant',
#  'lingering',
#  'dream',
#  'rather',
#  'newcomer',
#  'renaissance',
#  'Serampore',
#  'faces',
#  'Sufi',
#  'muster',
#  'However',
#  'Upper-class',
#  'Finally',
#  'contact',
#  'Take',
#  'Prize',
#  'Early',
#  'tributes',
#  'gearhead',
#  'occasional',
#  'Goutillon',
#  'At',
#  'Oh',
#  'sense',
#  'revealed',
#  'laughs',
#  'afford',
#  'Zacharias',
#  'elegance',
#  '2',
#  'affordability',
#  'giggled',
#  'BEST',
#  'disagreements',
#  'yeah',
#  'great',
#  'immersing',
#  'hung',
#  'showcasing',
#  'work',
#  'mockery',
#  'Aviv',
#  'many',
#  'something',
#  'cultures',
#  '“',
#  'Karkhanis',
#  'open',
#  'unpretentious',
#  'jewels',
#  'unending',
#  'disapproval',
#  'Farley',
#  'gourmands',
#  'refined',
#  'recounting',
#  'Turku',
#  'manager',
#  'Lensman',
#  'sailboat',
#  'sundeck',
#  'want',
#  'My',
#  'identity',
#  'Yards',
#  'Alex',
#  'though',
#  'Writer',
#  'industrious',
#  'chaat',
#  'Victoria',
#  'golden',
#  'front',
#  'shook',
#  'Kaushal',
#  'struck',
#  'inevitably',
#  'long-term',
#  'edition',
#  'close',
#  'facilitates',
#  'upon',
#  'reason',
#  'arrived',
#  'author',
#  'Told',
#  'empty',
#  'waged',
#  'beef',
#  'Enchanting',
#  'real',
#  'Turkish',
#  'The',
#  'recent',
#  'understated',
#  'Botswana',
#  'dolmades',
#  'chided',
#  'least',
#  'Terminus',
#  'exclusivity',
#  'world',
#  'understand',
#  'slight',
#  'account',
#  'anxiety',
#  'bubble',
#  'descriptions',
#  'need',
#  'much.',
#  'soon',
#  'classical',
#  'top',
#  'read',
#  'around',
#  'free',
#  'impressed',
#  'subcultures',
#  '(',
#  'Not',
#  ...]

# %%
# bag of words
import pandas as pd

def Bag_of_words(word_list):
    word_l = []
    for word in distinct_words:
        if (word in word_list) == True:
            word_l.append(word_list.count(word))
        else:
            word_l.append(0)
        
    return word_l

df = pd.DataFrame()
df["words"] = distinct_words
df["d1"] = Bag_of_words(d1)
df["d2"] = Bag_of_words(d2)
df["d3"] = Bag_of_words(d3)
df["d4"] = Bag_of_words(d4)
df["d5"] = Bag_of_words(d5)

    
print(df.head(100))
# Out:
#          words  d1  d2  d3  d4  d5
# 0       moment   0   0   0   0   1
# 1    genuinely   0   0   0   0   1
# 2    precisely   0   0   0   0   1
# 3         book   0   0   0   0   1
# 4        three   1   0   1   0   0
# ..         ...  ..  ..  ..  ..  ..
# 95      dinner   0   0   1   0   0
# 96   functions   1   0   0   0   0
# 97        fork   0   1   0   0   0
# 98         on…   0   0   0   0   1
# 99  nightclubs   0   0   0   0   1
#
# [100 rows x 6 columns]

# %%
#tf
import math

def TF(word_list):
    word_l = []
    for word in distinct_words:
        if (word in word_list) == True:
            word_l.append(1+math.log(1+math.log(word_list.count(word))))
        else:
            word_l.append(0)
        
    return word_l

tf = pd.DataFrame()
tf["words"] = distinct_words
tf["d1"] = TF(d1)
tf["d2"] = TF(d2)
tf["d3"] = TF(d3)
tf["d4"] = TF(d4)
tf["d5"] = TF(d5)
    
print(tf)
# Out:
#            words        d1   d2        d3        d4   d5
# 0         moment  0.000000  0.0  0.000000  0.000000  1.0
# 1      genuinely  0.000000  0.0  0.000000  0.000000  1.0
# 2      precisely  0.000000  0.0  0.000000  0.000000  1.0
# 3           book  0.000000  0.0  0.000000  0.000000  1.0
# 4          three  1.000000  0.0  1.000000  0.000000  0.0
# ...          ...       ...  ...       ...       ...  ...
# 1062      within  0.000000  0.0  0.000000  1.000000  0.0
# 1063  woman—took  0.000000  0.0  1.000000  0.000000  0.0
# 1064        mean  0.000000  1.0  0.000000  1.000000  0.0
# 1065           I  1.526589  1.0  1.741276  2.291725  1.0
# 1066    reminded  0.000000  1.0  1.000000  0.000000  0.0
#
# [1067 rows x 6 columns]

# %%
#idf
idf = pd.DataFrame()

def IDF():
    l = []
    D = [d1,d2,d3,d4,d5]
    for i in distinct_words:
        d = 0
        for j in D:
            if i in j:
                d+=1
                
        l.append(math.log(1+5/d))
        
    return l
        
idf["word"] = distinct_words
idf["relevance"] = IDF()

        
print(idf)
# Out:
#             word  relevance
# 0         moment   1.791759
# 1      genuinely   1.791759
# 2      precisely   1.791759
# 3           book   1.791759
# 4          three   1.252763
# ...          ...        ...
# 1062      within   1.791759
# 1063  woman—took   1.791759
# 1064        mean   1.252763
# 1065           I   0.693147
# 1066    reminded   1.252763
#
# [1067 rows x 2 columns]

# %%
#tf-idf
import numpy as np
tfidf = pd.DataFrame()
tfidf["words"] = distinct_words

n1 = np.array(tf.d1)
n2 = np.array(tf.d2)
n3 = np.array(tf.d3)
n4 = np.array(tf.d4)
n5 = np.array(tf.d5)
x = np.array(idf.relevance)

tfidf["d1"] = n1*x
tfidf["d2"] = n2*x
tfidf["d3"] = n3*x
tfidf["d4"] = n4*x
tfidf["d5"] = n5*x

print(tfidf)
# Out:
#            words        d1        d2        d3        d4        d5
# 0         moment  0.000000  0.000000  0.000000  0.000000  1.791759
# 1      genuinely  0.000000  0.000000  0.000000  0.000000  1.791759
# 2      precisely  0.000000  0.000000  0.000000  0.000000  1.791759
# 3           book  0.000000  0.000000  0.000000  0.000000  1.791759
# 4          three  1.252763  0.000000  1.252763  0.000000  0.000000
# ...          ...       ...       ...       ...       ...       ...
# 1062      within  0.000000  0.000000  0.000000  1.791759  0.000000
# 1063  woman—took  0.000000  0.000000  1.791759  0.000000  0.000000
# 1064        mean  0.000000  1.252763  0.000000  1.252763  0.000000
# 1065           I  1.058151  0.693147  1.206961  1.588502  0.693147
# 1066    reminded  0.000000  1.252763  1.252763  0.000000  0.000000
#
# [1067 rows x 6 columns]

# %%
#normalized tf-idf for docs
tfidf.d1/=len(distinct_words)
tfidf.d2/=len(distinct_words)
tfidf.d3/=len(distinct_words)
tfidf.d4/=len(distinct_words)
tfidf.d5/=len(distinct_words)
print(tfidf)
# Out:
#            words        d1        d2        d3        d4        d5
# 0         moment  0.000000  0.000000  0.000000  0.000000  0.001679
# 1      genuinely  0.000000  0.000000  0.000000  0.000000  0.001679
# 2      precisely  0.000000  0.000000  0.000000  0.000000  0.001679
# 3           book  0.000000  0.000000  0.000000  0.000000  0.001679
# 4          three  0.001174  0.000000  0.001174  0.000000  0.000000
# ...          ...       ...       ...       ...       ...       ...
# 1062      within  0.000000  0.000000  0.000000  0.001679  0.000000
# 1063  woman—took  0.000000  0.000000  0.001679  0.000000  0.000000
# 1064        mean  0.000000  0.001174  0.000000  0.001174  0.000000
# 1065           I  0.000992  0.000650  0.001131  0.001489  0.000650
# 1066    reminded  0.000000  0.001174  0.001174  0.000000  0.000000
#
# [1067 rows x 6 columns]

# %%
#cosine-similarity
import numpy as np
import math

cs = {}
q = 0
for i in np.array(tfidf.d5):
    q+=(i**2)
    
# print(q)

def cosine_sim(doc):
    d = 0
    for i in doc:
        d+=(i**2) 
        
#     print(d)
    a = doc.dot(np.array(tfidf.d5))
#     print(a)
#     return (a/(math.sqrt(q*d)))
    return('{0:.10f}'.format((a/(math.sqrt(q*d)))))

cs["d1"] = float(cosine_sim(np.array(tfidf.d1)))
cs["d2"] = float(cosine_sim(np.array(tfidf.d2)))
cs["d3"] = float(cosine_sim(np.array(tfidf.d3)))
cs["d4"] = float(cosine_sim(np.array(tfidf.d4)))
print(cs)
# Out:
# {'d1': 0.0698268963, 'd2': 0.0472304297, 'd3': 0.0524115398, 'd4': 0.0783768587}

# %%
#document ranking
def rank_doc(array):
    l = array.copy()
    valid = True
    while valid:
#         print(l)
        if(len(np.where(array == max(l))[0]) > 1):
            for i in range(len(np.where(array == max(l))[0])):
                print((np.where(array == max(l))[0][i]+1),)
            l = np.delete(l,np.where(l == max(l)),0)
        else:
            print(np.where(array == max(l))[0][0]+1)
            l = np.delete(l,np.where(l == max(l))[0],0)
            
        if(len(l) == 0):
            valid = False
            

rank_doc(np.array(list(cs.values())))
# Out:
# 4
# 1
# 3
# 2
