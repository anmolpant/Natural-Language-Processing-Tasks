# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
def extract_doc(doc):
    f = open(doc,"r", encoding='utf-8')
    data = f.read()
    word_tokens = word_tokenize(data)
    stop_words = list(set(stopwords.words('english')))
    filtered_sentence = []
    stopwords_list = []
    for w in word_tokens: 
        if w not in stop_words: 
            filtered_sentence.append(w)
        else:
            stopwords_list.append(w)
    
    return filtered_sentence

# %%
d1 = extract_doc(r"C:\Users\anmol\Downloads\natgeo1.txt")
d2 = extract_doc(r"C:\Users\anmol\Downloads\natgeo2.txt")
d3 = extract_doc(r"C:\Users\anmol\Downloads\natgeo3.txt")
d4 = extract_doc(r"C:\Users\anmol\Downloads\natgeo4.txt")

# %%
distinct_words = list(set(d1+d2+d3+d4))

# %%
distinct_words
# Out:
# ['world',
#  'panders',
#  'Chantilly',
#  'Lewis',
#  'heart',
#  'millions',
#  'extolling',
#  'happy',
#  'Early',
#  'lingering',
#  'today',
#  'outside',
#  'elegant',
#  'feelings',
#  'revelries',
#  'night',
#  'stays',
#  'Have',
#  'unforgettable',
#  'Age-style',
#  'must-haves',
#  'show',
#  'options',
#  'biases',
#  'journey',
#  'abroad',
#  'achievement',
#  'Turkey.',
#  'classical',
#  'little',
#  'bistro',
#  'amends',
#  'free',
#  'mob',
#  'barely',
#  'though',
#  'wrong',
#  'Indian-American',
#  'years',
#  'spurs',
#  'Dyed-in-the-wool',
#  'Writer',
#  'tourists',
#  'never-ending',
#  'inconvenienced',
#  'simply',
#  'yet',
#  'growing',
#  'wink',
#  'know',
#  'country',
#  'confound',
#  'recounting',
#  'weekend',
#  'glass',
#  'Bombay',
#  'London',
#  ',',
#  'road',
#  'almost',
#  'views',
#  'unlike',
#  'Gupta',
#  'arrived',
#  'Suspicions',
#  'Usain',
#  'holidays',
#  'dishes',
#  'another',
#  'nice',
#  'kind',
#  'pure',
#  'Our',
#  'pride',
#  'smiles',
#  'part-endearing',
#  'Riviera',
#  'emerging',
#  'winner',
#  'unpretentious',
#  'indulge',
#  'Mark',
#  'live',
#  'Enchanting',
#  'friend',
#  'National',
#  'someday',
#  '2',
#  'window',
#  'seems',
#  'lowdown',
#  'promise',
#  'Traveller',
#  'spent—or',
#  'setting',
#  'cuts',
#  'capital',
#  'mouths',
#  'BEST',
#  'Ghoda',
#  'Chinmai',
#  'battles',
#  'train',
#  'ruins',
#  'perfect',
#  'heartfelt',
#  'join',
#  'aesthetes',
#  'hung',
#  'characters',
#  'gentleman',
#  'side',
#  'wistful',
#  'feeling',
#  'showing',
#  'variety.',
#  'menu',
#  'meal',
#  'Reema',
#  'Goa',
#  'Rorschach',
#  'Dubrovnik',
#  'substantial',
#  'claim',
#  'When',
#  'abound',
#  'entitlement',
#  'marvel',
#  'words',
#  'matter',
#  'She',
#  'fill',
#  'least',
#  'restaurant',
#  'scanned',
#  'context',
#  'What',
#  'flits',
#  'sweet',
#  'finest',
#  'Akhil',
#  'manager',
#  'reap',
#  'comes',
#  'Luxury',
#  'Where',
#  'passes',
#  'hardly',
#  'heiress',
#  'never',
#  '#',
#  'counter',
#  'sings',
#  'shook',
#  'Atala',
#  'bus',
#  '13',
#  'desperately-trying-to-be-hip',
#  'enjoys',
#  'Dinakaran',
#  'head',
#  'Thiruvananthapuram',
#  'There',
#  'top',
#  'strong',
#  'unwarranted',
#  'Terminus',
#  'settle',
#  'number',
#  'seemed',
#  'predictability',
#  'cocktail',
#  'repulsed',
#  'Upper-class',
#  'turn',
#  'upon',
#  'Smart',
#  'drool-worthy',
#  'dances',
#  'test',
#  'overrated',
#  'asked',
#  'ill-prepared',
#  'tutorial',
#  'tell',
#  'cultures',
#  'kitchen',
#  'surprising',
#  'baba',
#  'real',
#  'fight',
#  'stern',
#  'confirmed',
#  'mayhem',
#  'dolmades',
#  'astute',
#  'Ardent',
#  'South',
#  'Tiffany',
#  'guide',
#  'close',
#  'refined',
#  'team',
#  'unending',
#  'Albert',
#  'Member',
#  'got',
#  'get',
#  'often',
#  'need',
#  'consider',
#  'suburbs',
#  'predilections',
#  'history',
#  'guided',
#  'differed',
#  'decadence',
#  'mainland',
#  'mystical',
#  'Chef',
#  'attitudes',
#  'aspire',
#  'One',
#  'itineraries',
#  'obtuse…',
#  'dry',
#  'nightclub',
#  'followed',
#  'Holly',
#  'cafés',
#  'Local',
#  'big',
#  'Times',
#  'monk',
#  'Forget',
#  'misplaced',
#  'Kala',
#  'Take',
#  'dull',
#  'could',
#  'York',
#  'seek',
#  'travel',
#  'granted',
#  'drinking',
#  'August',
#  'Let',
#  'dinner',
#  'showcasing',
#  'avowed',
#  'visitor',
#  'filling',
#  'observations',
#  'perhaps',
#  'countryside',
#  'surprises',
#  'wish',
#  'paeans',
#  'faraway',
#  'reminder',
#  'stand',
#  'best',
#  'crooked',
#  'manors',
#  'handful',
#  'colourful',
#  'highways',
#  'Twain',
#  'radioactive',
#  'befitting',
#  'really',
#  'directed',
#  'overpriced',
#  'Parliament',
#  'caused',
#  'retreats',
#  'rein',
#  'esteem',
#  'cosy',
#  'notice',
#  'heritage',
#  'account',
#  'last',
#  'Nights',
#  'hedonistic',
#  'universal',
#  'also',
#  'flagbearer',
#  'afoot',
#  'Shillong',
#  'coverage',
#  'glances',
#  'Bewitching',
#  'dominated',
#  'Alex',
#  'stretch',
#  'purse-strings',
#  'dessert',
#  'anywhere',
#  'want',
#  'section',
#  'entries',
#  'days',
#  'India',
#  'wanderlust.',
#  'dreamers',
#  'madness',
#  'Bangladesh',
#  'unearthed',
#  'bite',
#  'pow-wow',
#  'Shangri-La',
#  'toasts',
#  'castles',
#  'Zacharias',
#  'Train',
#  'Lensman',
#  'lucky',
#  'swirling',
#  'around',
#  'forays',
#  '!',
#  'sundeck',
#  'riveted',
#  'nothing—floating',
#  'reminisces',
#  'soon',
#  'impression',
#  'expert',
#  'crudest',
#  'leave',
#  'casual',
#  'far',
#  'Hajela',
#  '10',
#  'solutions',
#  'city',
#  'fun',
#  'grappling',
#  'owner',
#  'interesting',
#  'precarious',
#  'lasting',
#  'features',
#  'incoming',
#  'centrepiece',
#  'use',
#  'like',
#  'steak',
#  'new',
#  'making',
#  'example',
#  'grand',
#  'curries',
#  'three',
#  'four',
#  'satisfied',
#  'hard-knock',
#  'disagreements',
#  'usually',
#  'philosophers',
#  'glowing',
#  'exploration',
#  'acutely',
#  'glimpse',
#  'ocean',
#  'beeline',
#  'became',
#  'warmed',
#  'issue',
#  'venue',
#  'shrines',
#  'VT',
#  'industrious',
#  'fortnight',
#  'shopping',
#  'maestros',
#  'chaat',
#  'Islam',
#  'would',
#  'Europe',
#  'heard',
#  'feel',
#  'explore',
#  'respond',
#  'Dixit',
#  'Wealth',
#  'unchaperoned',
#  'it.',
#  'relation',
#  'Flash',
#  'term',
#  'final',
#  'eatery',
#  'within',
#  'incumbent',
#  'debate',
#  'His',
#  'baklava—a',
#  'Goutillon',
#  'English',
#  'facilitates',
#  'parts',
#  'things',
#  'champagne',
#  'many',
#  'journeys',
#  'something',
#  'Rhythm',
#  'distillation',
#  'bunch',
#  'December',
#  'Hampi',
#  'magazine',
#  'changed',
#  'dispatches',
#  'faithfully',
#  'As',
#  'trudging',
#  'drummed',
#  'giggled',
#  'producing',
#  'bravado',
#  'MotorcycleDiaries.',
#  'West',
#  'money',
#  'Jazz',
#  'Bring',
#  'allure',
#  'Prize',
#  'Mumbai',
#  'Golightly',
#  'pugilistic',
#  'different',
#  'Japan',
#  'go',
#  'sensuality',
#  'fairly',
#  'binge',
#  'see',
#  'always',
#  'Arre',
#  'stopped',
#  'gourmands',
#  'storied',
#  'traps',
#  'look',
#  'temperament',
#  'immersing',
#  'ground',
#  'Kaushal',
#  'part-comical',
#  'reclusive',
#  'Arabian',
#  'inner',
#  'chalkboard',
#  'front',
#  'Sharma',
#  'parsed',
#  'devout',
#  'inevitably',
#  'New',
#  'shade',
#  'every',
#  'reminded',
#  'Like',
#  'paradises',
#  'nooks',
#  'discovered',
#  'thank',
#  'impressed',
#  'later',
#  'Bewildering',
#  'backyard',
#  'anniversary',
#  'gallivanting',
#  'Asia',
#  '“',
#  'red',
#  'bubble',
#  'trails',
#  'Oh',
#  'narratives',
#  'atop',
#  'Abhishek',
#  'disapproval',
#  'held',
#  'studious',
#  'preach',
#  'grace',
#  'gluttony',
#  'rounded',
#  'Milan',
#  'hidden',
#  'music',
#  'wrote',
#  'gauche',
#  'sentiments',
#  'sailboat',
#  'struck',
#  'streets',
#  'rebellion—oh',
#  'appetite',
#  'eternally',
#  'French',
#  'several',
#  'Professional',
#  'contact',
#  'House',
#  'A',
#  'penny',
#  'itinerary',
#  'right',
#  'downsizers',
#  'offers',
#  'south',
#  'regular',
#  'credentials',
#  '10-minute',
#  'Indians',
#  'business',
#  'snobs',
#  'Le',
#  '?',
#  'along',
#  'Serampore',
#  'affordability',
#  'tiffs',
#  'pens',
#  'harp',
#  'Bolt',
#  'hurt',
#  'place',
#  'mockery',
#  'lay',
#  'end',
#  'everyday',
#  '0',
#  'special',
#  'featuring',
#  'filthy',
#  'used',
#  'made-for-Instagram',
#  ')',
#  'sigh',
#  'financial',
#  'fine',
#  'reveals',
#  'beauty',
#  'admiration',
#  'However',
#  'simple',
#  'evokes',
#  'backpacking',
#  'bit',
#  'sense',
#  'ever',
#  'wars',
#  ';',
#  'person',
#  'Shashi',
#  'Bengal',
#  'reach',
#  'solo',
#  'exclusivity',
#  'sea',
#  'spend',
#  'locals',
#  'Spotting',
#  'tastes',
#  'either',
#  'sixth',
#  'We',
#  'truth',
#  'extra',
#  '’',
#  'stench',
#  'For',
#  'meat',
#  'straight',
#  'loafer',
#  'decodes',
#  'hosting',
#  'especially',
#  'Rajasthan',
#  'take',
#  'writers',
#  'tributes',
#  'anxiety',
#  'air',
#  'Raghu',
#  'navigate',
#  'Unable',
#  'buy',
#  'NGTI',
#  'first',
#  'think',
#  '”',
#  'Olympics',
#  'question',
#  'Churchgate',
#  'palace',
#  'cruise',
#  'travelling',
#  'gospel',
#  '—the',
#  'told',
#  'physical',
#  'exclamations',
#  'woman—took',
#  'understated',
#  'seen',
#  'call',
#  'billionaire',
#  'muster',
#  'sweaty',
#  'To',
#  'independent',
#  'man',
#  'give',
#  'functions',
#  'privileges',
#  'open-minded',
#  'chose',
#  'institutions—a',
#  'fork',
#  'schooling',
#  'graduation',
#  'precise',
#  'game',
#  'domestic',
#  'home',
#  'year',
#  'feasts',
#  'About',
#  'wallet',
#  'Mysore',
#  'Anniversary',
#  'ballroom',
#  'celebrated',
#  'elegance',
#  'edition',
#  'shop',
#  'Sizing',
#  'people',
#  'Victoria',
#  'Turkish',
#  'coming',
#  'towards',
#  'ode',
#  'minimalists',
#  'Farley',
#  'revealed',
#  'sometimes',
#  'hotel',
#  'injury',
#  'worth',
#  'Vaishali',
#  'Nobel',
#  '(',
#  'standing',
#  'adventurous',
#  'musician',
#  'drives',
#  'passing',
#  'Bourdain',
#  'brave',
#  'true',
#  'media',
#  'hometowns',
#  'us',
#  'traditional',
#  'requested',
#  'Thomas',
#  'rephrase',
#  'newcomer',
#  'perusing',
#  'tourist',
#  'stumble',
#  'Then',
#  'Molotov',
#  'landscape',
#  'Hyderabad',
#  'become',
#  'favourite',
#  'sayings',
#  'traveller',
#  'exotification',
#  'gives',
#  'server—a',
#  'gearhead',
#  'walks',
#  'Iranian',
#  'access',
#  'across',
#  'blame',
#  'well',
#  'Maldives',
#  'infinitely',
#  'gathers',
#  'Geographic',
#  'Ladakh',
#  'maiden',
#  'wine',
#  'confines',
#  'travellers',
#  'permitted',
#  'unexpected',
#  'intertwined',
#  'Travel',
#  'gully',
#  'eyebrow-cocked',
#  'stay',
#  'Dubai',
#  'ultra-indulgence',
#  'fruit-laden',
#  'companions',
#  'David',
#  'recreational',
#  'choose',
#  'come',
#  'sample',
#  'typical',
#  'finish',
#  'faces',
#  'unknown',
#  'list',
#  'slogging',
#  'readers',
#  'lies',
#  'gnawing',
#  'writer',
#  'At',
#  'time',
#  'Hacks',
#  'ways',
#  'others',
#  'pilgrimage',
#  'Sufi',
#  'Delhi',
#  'Chowpatty',
#  'haleem',
#  'aware',
#  'featured',
#  'back',
#  'Janice',
#  'culture',
#  'knowing',
#  'empty',
#  'elite',
#  'privy',
#  'Besides',
#  'waged',
#  'madcap',
#  'renaissance',
#  'dazed',
#  'dashed',
#  'Grecian',
#  'America',
#  'pair',
#  'chided',
#  'shots',
#  'centre',
#  'pow-wow.',
#  'make',
#  'one',
#  'returned',
#  'visit',
#  'way',
#  'mind',
#  'deserve',
#  'myriad',
#  'gyrating',
#  'adopted',
#  'Yes.',
#  'I',
#  'Canteen',
#  'sunglasses',
#  'Living',
#  'Antoine',
#  'slacking',
#  'smacked',
#  'royalty',
#  'hankering',
#  'local',
#  'If',
#  'slight',
#  'Extravagance',
#  'former',
#  'examples',
#  'After',
#  'eccentric',
#  'practising',
#  'guidebook-toting',
#  'roundup',
#  'Some',
#  'It',
#  'fare',
#  'recent',
#  'Last',
#  'editions',
#  'food',
#  'past',
#  'pejorative',
#  'haunts',
#  'compatriot',
#  'backpack',
#  'personal',
#  'contrast',
#  'Pariat',
#  'authenticity',
#  'particularly',
#  'feature',
#  '.',
#  'mean',
#  'Kolkata',
#  'China',
#  'declared',
#  'Korea',
#  'Karkhanis',
#  'Banaras',
#  'insiders',
#  'month',
#  'pretend',
#  'khau',
#  'author',
#  'The',
#  'stance',
#  'Botswana',
#  'much.',
#  'emboldened',
#  'lived',
#  'They',
#  'picks',
#  'yeah',
#  'pride—we',
#  'Tharoor',
#  'private',
#  ':',
#  'might',
#  'And',
#  'Anthony',
#  'year-end',
#  'found',
#  'whether',
#  'France',
#  'rest',
#  'flâneur',
#  'proud',
#  'memorable',
#  'spikier',
#  'prepared',
#  'This',
#  'subcultures',
#  'comfortable',
#  'stories',
#  'veer',
#  'desi',
#  'bears',
#  'All',
#  'In',
#  'day',
#  'no-nonsense',
#  'open',
#  'getting',
#  'Read',
#  'afford',
#  'games',
#  'manifold',
#  'Einstein',
#  'descriptors',
#  'My',
#  'pleasures',
#  'taught',
#  'pristine',
#  'one…',
#  'baklava',
#  'fuss',
#  'staple',
#  'Libya',
#  '1990s',
#  'Who',
#  'luxury',
#  'prompted',
#  'identity',
#  'minimum',
#  'jewels',
#  'conservatively',
#  'beef',
#  'maybe']

# %%
# bag of words
import pandas as pd

def Bag_of_words(word_list):
    word_l = []
    for word in distinct_words:
        if (word in word_list) == True:
            word_l.append(word_list.count(word))
        else:
            word_l.append(0)
        
    return word_l

df = pd.DataFrame()
df["words"] = distinct_words
df["d1"] = Bag_of_words(d1)
df["d2"] = Bag_of_words(d2)
df["d3"] = Bag_of_words(d3)
df["d4"] = Bag_of_words(d4)

    
print(df.head(100))
# Out:
#         words  d1  d2  d3  d4
# 0       world   1   0   1   1
# 1     panders   0   1   0   0
# 2   Chantilly   0   0   1   0
# 3       Lewis   0   0   1   0
# 4       heart   0   1   1   1
# ..        ...  ..  ..  ..  ..
# 95       cuts   0   0   1   0
# 96    capital   0   0   1   0
# 97     mouths   0   0   0   1
# 98       BEST   0   0   0   1
# 99      Ghoda   0   0   0   1
#
# [100 rows x 5 columns]

# %%
#tf
import math

def TF(word_list):
    word_l = []
    for word in distinct_words:
        if (word in word_list) == True:
            word_l.append(1+math.log(1+math.log(word_list.count(word))))
        else:
            word_l.append(0)
        
    return word_l

tf = pd.DataFrame()
tf["words"] = distinct_words
tf["d1"] = TF(d1)
tf["d2"] = TF(d2)
tf["d3"] = TF(d3)
tf["d4"] = TF(d4)
    
print(tf)
# Out:
#               words   d1   d2   d3   d4
# 0             world  1.0  0.0  1.0  1.0
# 1           panders  0.0  1.0  0.0  0.0
# 2         Chantilly  0.0  0.0  1.0  0.0
# 3             Lewis  0.0  0.0  1.0  0.0
# 4             heart  0.0  1.0  1.0  1.0
# ..              ...  ...  ...  ...  ...
# 885         minimum  0.0  0.0  0.0  1.0
# 886          jewels  0.0  1.0  0.0  0.0
# 887  conservatively  0.0  0.0  1.0  0.0
# 888            beef  0.0  0.0  1.0  0.0
# 889           maybe  1.0  0.0  0.0  0.0
#
# [890 rows x 5 columns]

# %%
#idf
idf = pd.DataFrame()

def IDF():
    l = []
    D = [d1,d2,d3,d4]
    for i in distinct_words:
        d = 0
        for j in D:
            if i in j:
                d+=1
                
        l.append(math.log(1+4/d))
        
    return l
        
idf["word"] = distinct_words
idf["relevance"] = IDF()

        
print(idf)
# Out:
#                word  relevance
# 0             world   0.847298
# 1           panders   1.609438
# 2         Chantilly   1.609438
# 3             Lewis   1.609438
# 4             heart   0.847298
# ..              ...        ...
# 885         minimum   1.609438
# 886          jewels   1.609438
# 887  conservatively   1.609438
# 888            beef   1.609438
# 889           maybe   1.609438
#
# [890 rows x 2 columns]

# %%
#tf-idf
import numpy as np
tfidf = pd.DataFrame()
tfidf["words"] = distinct_words

n1 = np.array(tf.d1)
n2 = np.array(tf.d2)
n3 = np.array(tf.d3)
n4 = np.array(tf.d4)
x = np.array(idf.relevance)

tfidf["d1"] = n1*x
tfidf["d2"] = n2*x
tfidf["d3"] = n3*x
tfidf["d4"] = n4*x

print(tfidf)
# Out:
#               words        d1        d2        d3        d4
# 0             world  0.847298  0.000000  0.847298  0.847298
# 1           panders  0.000000  1.609438  0.000000  0.000000
# 2         Chantilly  0.000000  0.000000  1.609438  0.000000
# 3             Lewis  0.000000  0.000000  1.609438  0.000000
# 4             heart  0.000000  0.847298  0.847298  0.847298
# ..              ...       ...       ...       ...       ...
# 885         minimum  0.000000  0.000000  0.000000  1.609438
# 886          jewels  0.000000  1.609438  0.000000  0.000000
# 887  conservatively  0.000000  0.000000  1.609438  0.000000
# 888            beef  0.000000  0.000000  1.609438  0.000000
# 889           maybe  1.609438  0.000000  0.000000  0.000000
#
# [890 rows x 5 columns]

# %%
#normalized tf-idf for docs
tfidf.d1/=len(distinct_words)
tfidf.d2/=len(distinct_words)
tfidf.d3/=len(distinct_words)
tfidf.d4/=len(distinct_words)
print(tfidf)
# Out:
#               words        d1        d2        d3        d4
# 0             world  0.000952  0.000000  0.000952  0.000952
# 1           panders  0.000000  0.001808  0.000000  0.000000
# 2         Chantilly  0.000000  0.000000  0.001808  0.000000
# 3             Lewis  0.000000  0.000000  0.001808  0.000000
# 4             heart  0.000000  0.000952  0.000952  0.000952
# ..              ...       ...       ...       ...       ...
# 885         minimum  0.000000  0.000000  0.000000  0.001808
# 886          jewels  0.000000  0.001808  0.000000  0.000000
# 887  conservatively  0.000000  0.000000  0.001808  0.000000
# 888            beef  0.000000  0.000000  0.001808  0.000000
# 889           maybe  0.001808  0.000000  0.000000  0.000000
#
# [890 rows x 5 columns]
